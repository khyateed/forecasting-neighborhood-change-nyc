# %%
import pandas as pd
import numpy as np

# %%
df_race = pd.DataFrame()

years = ['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022']

for year in years:
    df = pd.read_csv(f"Data/ACS{year}_race.csv")
    df['year'] = year
    df = df[['GEO_ID','year', 'NAME', 'B02001_001E', 'B02001_002E','B02001_003E', 'B02001_004E',
       'B02001_005E', 'B02001_006E', 'B02001_007E', 'B02001_008E', 'B02001_009E', 'B02001_010E' ]]
    df_race = pd.concat([df_race, df], axis=0)
df_race.head()
# Out:
#                  GEO_ID  year                                        NAME  \
# 0             Geography  2010                        Geographic Area Name
# 1  1400000US36001000100  2010     Census Tract 1, Albany County, New York
# 2  1400000US36001000200  2010     Census Tract 2, Albany County, New York
# 3  1400000US36001000300  2010     Census Tract 3, Albany County, New York
# 4  1400000US36001000401  2010  Census Tract 4.01, Albany County, New York
#
#        B02001_001E                   B02001_002E  \
# 0  Estimate!!Total  Estimate!!Total!!White alone
# 1             2308                           875
# 2             5506                           633
# 3             6471                          3047
# 4             2211                          1938
#
#                                         B02001_003E  \
# 0  Estimate!!Total!!Black or African American alone
# 1                                              1207
# 2                                              4261
# ...

# %%
# change headers
df_race.columns = df_race.iloc[0,:]

# limit to NYC counties
df_race = df_race[df_race["Geographic Area Name"].str.contains('New York County|Bronx County|Richmond County|Kings County|Queens County')]
df_race
# Out:
# 0                Geography  2010  \
# 89    1400000US36005000100  2010
# 90    1400000US36005000200  2010
# 91    1400000US36005000400  2010
# 92    1400000US36005001600  2010
# 93    1400000US36005001900  2010
# ...                    ...   ...
# 4298  1400000US36085030302  2022
# 4299  1400000US36085031901  2022
# 4300  1400000US36085031902  2022
# 4301  1400000US36085032300  2022
# 4302  1400000US36085990100  2022
#
# 0                               Geographic Area Name Estimate!!Total  \
# 89            Census Tract 1, Bronx County, New York           11517
# 90            Census Tract 2, Bronx County, New York            4286
# 91            Census Tract 4, Bronx County, New York            4893
# 92           Census Tract 16, Bronx County, New York            5140
# 93           Census Tract 19, Bronx County, New York            2142
# ...                                              ...             ...
# 4298  Census Tract 303.02; Richmond County; New York            6374
# ...
